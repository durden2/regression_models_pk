# %%
dataLab = read.csv("C:\\Users\\micha\\Desktop\\PK\\II semestr\\Modele Regresji\\Final Project\\regression_models_pk\\hour.csv")
head(dataLab)
# Out:
#   instant dteday     season yr mnth hr holiday weekday workingday weathersit
# 1 1       2011-01-01 1      0  1    0  0       6       0          1
# 2 2       2011-01-01 1      0  1    1  0       6       0          1
# 3 3       2011-01-01 1      0  1    2  0       6       0          1
# 4 4       2011-01-01 1      0  1    3  0       6       0          1
# 5 5       2011-01-01 1      0  1    4  0       6       0          1
# 6 6       2011-01-01 1      0  1    5  0       6       0          2
#   temp atemp  hum  windspeed casual registered cnt
# 1 0.24 0.2879 0.81 0.0000    3      13         16
# 2 0.22 0.2727 0.80 0.0000    8      32         40
# 3 0.22 0.2727 0.80 0.0000    5      27         32
# 4 0.24 0.2879 0.75 0.0000    3      10         13
# 5 0.24 0.2879 0.75 0.0000    0       1          1
# 6 0.24 0.2576 0.75 0.0896    0       1          1

# %%
summary(dataLab)
# Out:
#     instant             dteday          season            yr
#  Min.   :    1   2011-01-01:   24   Min.   :1.000   Min.   :0.0000
#  1st Qu.: 4346   2011-01-08:   24   1st Qu.:2.000   1st Qu.:0.0000
#  Median : 8690   2011-01-09:   24   Median :3.000   Median :1.0000
#  Mean   : 8690   2011-01-10:   24   Mean   :2.502   Mean   :0.5026
#  3rd Qu.:13034   2011-01-13:   24   3rd Qu.:3.000   3rd Qu.:1.0000
#  Max.   :17379   2011-01-15:   24   Max.   :4.000   Max.   :1.0000
#                  (Other)   :17235
#       mnth              hr           holiday           weekday
#  Min.   : 1.000   Min.   : 0.00   Min.   :0.00000   Min.   :0.000
#  1st Qu.: 4.000   1st Qu.: 6.00   1st Qu.:0.00000   1st Qu.:1.000
#  Median : 7.000   Median :12.00   Median :0.00000   Median :3.000
#  Mean   : 6.538   Mean   :11.55   Mean   :0.02877   Mean   :3.004
#  3rd Qu.:10.000   3rd Qu.:18.00   3rd Qu.:0.00000   3rd Qu.:5.000
#  Max.   :12.000   Max.   :23.00   Max.   :1.00000   Max.   :6.000
#
# ...

# %%
scatter.smooth(x=dataLab$cnt, y=dataLab$hum, main="Count ~ Temp")
# Out:
# Plot with title "Count ~ Temp"

# %%
par(mfrow=c(1, 3))

boxplot(dataLab$hum, main="hum")
boxplot(dataLab$casual, main="casual")
boxplot(dataLab$registered, main="registered")
        
#boxplot.stats(dataLab$casual)$out - uncomment to print all outliers
# Out:
# Plot with title "registered"

# %%
library(e1071)
plot(density(dataLab$cnt), main="Density Plot: Speed", ylab="Frequency", sub=paste("Skewness:", round(e1071::skewness(dataLab$cnt), 2)))
# Out:
# Plot with title "Density Plot: Speed"

# %%
plot(dataLab)

# %%
model <- lm(dataLab$cnt~dataLab$hum)
par(mfrow=c(2, 2))
plot(model)
# Out:
# Plot with title ""
